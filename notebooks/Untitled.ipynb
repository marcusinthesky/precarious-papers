# %%
# %reload_kedro
# Out:
# 2020-02-26 20:53:37,903 - root - INFO - ** Kedro project precarious-papers
# 2020-02-26 20:53:37,904 - root - INFO - Defined global variable `context` and `catalog`

# %%
context.io.load('remote_famafrenchfivefactordaily_data')
# Out:
# 2020-02-26 20:53:38,672 - kedro.io.data_catalog - INFO - Loading data from `remote_famafrenchfivefactordaily_data` (CSVDataSet)...
#           Mkt-RF   SMB   HML   RMW   CMA     RF
# 19630701   -0.67  0.00 -0.32 -0.01  0.15  0.012
# 19630702    0.79 -0.27  0.27 -0.07 -0.19  0.012
# 19630703    0.63 -0.17 -0.09  0.17 -0.33  0.012
# 19630705    0.40  0.08 -0.28  0.08 -0.33  0.012
# 19630708   -0.63  0.04 -0.18 -0.29  0.13  0.012
# ...          ...   ...   ...   ...   ...    ...
# 20200127   -1.56  0.27 -0.48 -0.59  0.05  0.006
# 20200128    1.02 -0.15 -0.42  0.17 -0.10  0.006
# 20200129   -0.10 -0.44 -0.95  0.25  0.19  0.006
# 20200130    0.34 -0.64  0.67 -0.39 -0.11  0.006
# 20200131   -1.74 -0.52 -0.34 -0.54 -0.69  0.006
#
# [14244 rows x 6 columns]
